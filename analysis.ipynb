# %%
import pandas as pd

df = pd.read_csv("data/raw/energy_data.csv")

df.head()
# Out:
#              timestamp  fridge    ac  lights  microwave  total_power
# 0  2023-01-01 00:00:00     119     0      73          0          192
# 1  2023-01-01 01:00:00     134     0       0          0          134
# 2  2023-01-01 02:00:00       0  1551      73          0         1624
# 3  2023-01-01 03:00:00       0     0      66          0           66
# 4  2023-01-01 04:00:00      83     0      86          0          169

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4321 entries, 0 to 4320
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   timestamp    4321 non-null   str
#  1   fridge       4321 non-null   int64
#  2   ac           4321 non-null   int64
#  3   lights       4321 non-null   int64
#  4   microwave    4321 non-null   int64
#  5   total_power  4321 non-null   int64
# dtypes: int64(5), str(1)
# memory usage: 202.7 KB

# %%
df.describe()
# Out:
#             fridge           ac       lights    microwave  total_power
# count  4321.000000  4321.000000  4321.000000  4321.000000  4321.000000
# mean     87.443879   796.835686    30.920157   100.104374  1015.304096
# std      67.326252   917.562758    33.932823   303.073549   975.395387
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000   125.000000
# 50%      93.000000     0.000000    23.000000     0.000000   973.000000
# 75%     145.000000  1672.000000    61.000000     0.000000  1871.000000
# max     199.000000  2499.000000    99.000000  1199.000000  3875.000000

# %%
df[['fridge','ac','lights','microwave','total_power']].mean()
# Out:
# fridge           87.443879
# ac              796.835686
# lights           30.920157
# microwave       100.104374
# total_power    1015.304096
# dtype: float64

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'])

# %%
import pandas as pd
df=pd.read_csv("data/raw/energy_data.csv")
df['timestamp'] = pd.to_datetime(df['timestamp'])

# %%
import matplotlib.pyplot as plt

plt.figure()
daily['total_power'].plot()
plt.title("Daily Energy Consumption")
plt.xlabel("Date")
plt.ylabel("Power (Watts)")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 4
#       1 import matplotlib.pyplot as plt
#       3 plt.figure()
# ----> 4 daily['total_power'].plot()
#       5 plt.title("Daily Energy Consumption")
#       6 plt.xlabel("Date")
#
# NameError: name 'daily' is not defined

# %%
daily = df.resample('D', on='timestamp').sum()
daily.head()
# Out:
#             fridge    ac  lights  microwave  total_power
# timestamp
# 2023-01-01    1726  6748     863       3827        13164
# 2023-01-02    1698  3295     721       3754         9468
# 2023-01-03    2266  3023     828       3347         9464
# 2023-01-04    1938  9267     676       2869        14750
# 2023-01-05    2293  1556     915       1176         5940

# %%
import matplotlib.pyplot as plt

plt.figure()
daily['total_power'].plot()
plt.title("Daily Energy Consumption")
plt.xlabel("Date")
plt.ylabel("Power (Watts)")
plt.show()

# %%
df[['fridge','ac','lights','microwave','total_power']].mean()
# Out:
# fridge           87.443879
# ac              796.835686
# lights           30.920157
# microwave       100.104374
# total_power    1015.304096
# dtype: float64

# %%
kitchen_cols = ['fridge' , 'ac' , 'lights' , 'microwave' ]
available_cols = [c for c in kitchen_cols if c in df.columns]
df_kitchen = df[available_cols]
df_kitchen.describe()
# Out:
#             fridge           ac       lights    microwave
# count  4321.000000  4321.000000  4321.000000  4321.000000
# mean     87.443879   796.835686    30.920157   100.104374
# std      67.326252   917.562758    33.932823   303.073549
# min       0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000
# 50%      93.000000     0.000000    23.000000     0.000000
# 75%     145.000000  1672.000000    61.000000     0.000000
# max     199.000000  2499.000000    99.000000  1199.000000

# %%
df_kitchen.sum()
# Out:
# fridge        377845
# ac           3443127
# lights        133606
# microwave     432551
# dtype: int64

# %%
df_kitchen.head()
# Out:
#    fridge    ac  lights  microwave
# 0     119     0      73          0
# 1     134     0       0          0
# 2       0  1551      73          0
# 3       0     0      66          0
# 4      83     0      86          0

# %%
df.shape
# Out:
# (4321, 6)

# %%
df.isnull().sum()
# Out:
# timestamp      0
# fridge         0
# ac             0
# lights         0
# microwave      0
# total_power    0
# dtype: int64

# %%
df.isnull()
# Out:
#       timestamp  fridge     ac  lights  microwave  total_power
# 0         False   False  False   False      False        False
# 1         False   False  False   False      False        False
# 2         False   False  False   False      False        False
# 3         False   False  False   False      False        False
# 4         False   False  False   False      False        False
# ...         ...     ...    ...     ...        ...          ...
# 4316      False   False  False   False      False        False
# 4317      False   False  False   False      False        False
# 4318      False   False  False   False      False        False
# 4319      False   False  False   False      False        False
# 4320      False   False  False   False      False        False
#
# [4321 rows x 6 columns]

# %%
df.isnull().values.any()
# Out:
# np.False_

# %%
df.tail()
# Out:
#                timestamp  fridge    ac  lights  microwave  total_power
# 4316 2023-06-29 20:00:00       0     0      28          0           28
# 4317 2023-06-29 21:00:00     112  1749       0          0         1861
# 4318 2023-06-29 22:00:00     139  1294      67          0         1500
# 4319 2023-06-29 23:00:00      90     0      59          0          149
# 4320 2023-06-30 00:00:00     140  2283      98          0         2521

# %%
daily.to_csv("data/processed_daily_energy.csv")

# %%
daily = df.resample('D', on='timestamp').sum()
