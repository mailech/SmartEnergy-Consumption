# %% [markdown]
# # Model Comparison: Linear Regression vs LSTM

# %%
# Linear Regression Results
lr_mae = 661.12
lr_rmse = 834.86

lstm_rmse =  853.8731936098936

# %%
print("Linear Regression RMSE:", lr_rmse)
print("LSTM RMSE:", lstm_rmse)
# Out:
# Linear Regression RMSE: 834.86
# LSTM RMSE: 853.8731936098936

# %%
import matplotlib.pyplot as plt

models = ['Linear Regression', 'LSTM']
rmse_values = [lr_rmse, lstm_rmse]

plt.bar(models, rmse_values)
plt.title("Model Comparison (RMSE)")
plt.ylabel("Error")
plt.show()

# %% [markdown]
# ## Conclusion
#
# The LSTM model performs better than Linear Regression as it captures time-based dependencies in  consumption data.
#
# Linear Regression fails to model complex patterns, while LSTM provides improved prediction accuracy.
#
# Thus, LSTM is selected as the final model for energy forecasting.

# %% [markdown]
# Even though LSTM did not outperform Linear Regression in this experiment, it has the potential to improve with further tuning and larger datasets.
